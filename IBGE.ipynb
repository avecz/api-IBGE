201511|201512|201601|201602|201603|201604|201605|201606|201607|201608|201609|201610|201611|201612|201701|201702|201703|201704|201705|201706|201707|201708|201709|201710|201711|201712|201801|201802|201803|201804|201805|201806|201807|201808|201809|201810|201811|201812|201901|201902|201903|201904|201905|201906|201907|201908|201909|201910|201911|201912|202001|202002|202003|202004|202005|202006|202007|202008|202009|202010|202011|202012|202101|202102|202103|202104|202105|202106|202107|202108|202109|202110|202111|202112|202201|202202|202203|202204|202205|202206|202207|202208|202209|202210|202211/variaveis/63|2263|2264|69|2265?localidades=N1[all]'

# %%
 
with urllib.request.urlopen(query) as url:
    data = url.read().decode('utf-8')
    data = json.loads(data)

# %% [markdown]
# ***

# %% [markdown]
# https://www.skytowner.com/explore/splitting_dictionary_into_separate_columns_in_pandas_dataframe

# %%
df = pd.read_json(json.dumps(data))

# %%
df
# Out:
#      id                               variavel unidade  \
# 0    63                 IPCA - Variação mensal
# 1  2263   IPCA - Variação acumulada em 3 meses
# 2  2264   IPCA - Variação acumulada em 6 meses
# 3    69       IPCA - Variação acumulada no ano
# 4  2265  IPCA - Variação acumulada em 12 meses
#
#                                           resultados
# 0  [{'classificacoes': [], 'series': [{'localidad...
# 1  [{'classificacoes': [], 'series': [{'localidad...
# 2  [{'classificacoes': [], 'series': [{'localidad...
# 3  [{'classificacoes': [], 'series': [{'localidad...
# 4  [{'classificacoes': [], 'series': [{'localidad...

# %%
# remover id para evitar conflitos, pois existem diversos ids na base
df.drop(columns='id', inplace=True)

# %% [markdown]
# ## Data Clean

# %%
df_clean = df.copy()

# %% [markdown]
# ### coluna resultados

# %%
# a coluna 'resultados' contém uma lista para cada UF.
# utilizar o explode: https://stackoverflow.com/questions/27263805/pandas-column-of-lists-create-a-row-for-each-list-element

df_clean = df_clean.explode('resultados').reset_index(drop=True)

# %%
df_clean = pd.concat([df_clean, df_clean['resultados'].apply(pd.Series)], axis=1)
df_clean.drop(columns='resultados',inplace=True)

# %%
df_clean
# Out:
#                                 variavel unidade classificacoes  \
# 0                 IPCA - Variação mensal                     []
# 1   IPCA - Variação acumulada em 3 meses                     []
# 2   IPCA - Variação acumulada em 6 meses                     []
# 3       IPCA - Variação acumulada no ano                     []
# 4  IPCA - Variação acumulada em 12 meses                     []
#
#                                               series
# 0  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 1  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 2  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 3  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 4  [{'localidade': {'id': '1', 'nivel': {'id': 'N...

# %% [markdown]
# ### coluna classificações

# %%
# TO DO: verificar se a col classificacoes possui dados

# o conteúdo da coluna 'classificacoes'
# está em uma lista com 1 elemento.
# extrair, deixando apenas o conteúdo em json/dict
# aplicar o pd.series para transformar os json/dict
# em linhas
try:
    df_clean = pd.concat([df_clean, df_clean['classificacoes'].apply(lambda x: x[0]).apply(pd.Series)], axis=1)
    # coluna 'classificacoes' dividida em 'id', 'nome' e 'categoria'
    # 1. remover id e nome
    df_clean.drop(columns=['id', 'nome'], inplace=True)
    # 2. na coluna 'categoria' existem os ids e nome das espécies em um dict. Manter apenas as espécies
    # extrair valores de um dict ### https://bobbyhadz.com/blog/python-get-first-value-in-dictionary
    df_clean['categoria'] = df_clean['categoria'].apply(lambda x: list(x.values())[0])
    # 3. renomear 'categoria' para 'espécie'
    df_clean.rename(columns={'categoria': 'espécie'}, inplace=True)
except:
    pass
# remover as colunas
df_clean.drop(columns=['classificacoes'],inplace=True)

# %%
df_clean
# Out:
#                                 variavel unidade  \
# 0                 IPCA - Variação mensal
# 1   IPCA - Variação acumulada em 3 meses
# 2   IPCA - Variação acumulada em 6 meses
# 3       IPCA - Variação acumulada no ano
# 4  IPCA - Variação acumulada em 12 meses
#
#                                               series
# 0  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 1  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 2  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 3  [{'localidade': {'id': '1', 'nivel': {'id': 'N...
# 4  [{'localidade': {'id': '1', 'nivel': {'id': 'N...

# %% [markdown]
# ### coluna 'series'

# %%
# a coluna 'series' contém uma lista para cada UF.
# utilizar o explode: https://stackoverflow.com/questions/27263805/pandas-column-of-lists-create-a-row-for-each-list-element

df_clean = df_clean.explode('series').reset_index(drop=True)

# %%
df_clean
# Out:
#                                 variavel unidade  \
# 0                 IPCA - Variação mensal
# 1   IPCA - Variação acumulada em 3 meses
# 2   IPCA - Variação acumulada em 6 meses
# 3       IPCA - Variação acumulada no ano
# 4  IPCA - Variação acumulada em 12 meses
#
#                                               series
# 0  {'localidade': {'id': '1', 'nivel': {'id': 'N1...
# 1  {'localidade': {'id': '1', 'nivel': {'id': 'N1...
# 2  {'localidade': {'id': '1', 'nivel': {'id': 'N1...
# 3  {'localidade': {'id': '1', 'nivel': {'id': 'N1...
# 4  {'localidade': {'id': '1', 'nivel': {'id': 'N1...

# %%
# expandir "series"
df_clean = pd.concat([df_clean, df_clean['series'].apply(pd.Series)], axis=1)
# remover as colunas
df_clean.drop(columns=['series'],inplace=True)

# %%
df_clean
# Out:
#                                 variavel unidade  \
# 0                 IPCA - Variação mensal
# 1   IPCA - Variação acumulada em 3 meses
# 2   IPCA - Variação acumulada em 6 meses
# 3       IPCA - Variação acumulada no ano
# 4  IPCA - Variação acumulada em 12 meses
#
#                                           localidade  \
# 0  {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Bra...
# 1  {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Bra...
# 2  {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Bra...
# 3  {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Bra...
# 4  {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Bra...
#
#                                                serie
# 0  {'197912': '...', '198001': '6.62', '198002': ...
# 1  {'197912': '...', '198001': '...', '198002': '...
# 2  {'197912': '...', '198001': '...', '198002': '...
# 3  {'197912': '...', '198001': '6.62', '198002': ...
# 4  {'197912': '...', '198001': '...', '198002': '...

# %%
# coluna 'series' dividida em 'localidade' e 'serie'
df_clean = pd.concat([df_clean, df_clean['localidade'].apply(pd.Series)], axis=1)
df_clean = pd.concat([df_clean, df_clean['serie'].apply(pd.Series)], axis=1)
df_clean.drop(columns=['localidade','serie'], inplace=True)

# %%
df_clean
# Out:
#                                 variavel unidade id  \
# 0                 IPCA - Variação mensal          1
# 1   IPCA - Variação acumulada em 3 meses          1
# 2   IPCA - Variação acumulada em 6 meses          1
# 3       IPCA - Variação acumulada no ano          1
# 4  IPCA - Variação acumulada em 12 meses          1
#
#                             nivel    nome 197912 198001 198002 198003 198004  \
# 0  {'id': 'N1', 'nome': 'Brasil'}  Brasil    ...   6.62   4.62   6.04   5.29
# 1  {'id': 'N1', 'nome': 'Brasil'}  Brasil    ...    ...    ...  18.27  16.80
# 2  {'id': 'N1', 'nome': 'Brasil'}  Brasil    ...    ...    ...    ...    ...
# 3  {'id': 'N1', 'nome': 'Brasil'}  Brasil    ...   6.62  11.54  18.27  24.53
# 4  {'id': 'N1', 'nome': 'Brasil'}  Brasil    ...    ...    ...    ...    ...
#
#    ... 202202 202203 202204 202205 202206 202207 202208 202209 202210 202211
# 0  ...   1.01   1.62   1.06   0.47   0.67  -0.68  -0.36  -0.29   0.59   0.41
# 1  ...   2.30   3.20   3.73   3.18   2.22   0.46  -0.37  -1.32  -0.06   0.71
# 2  ...   5.77   6.25   6.05   5.55   5.49   4.21   2.79   0.86   0.39   0.33
# 3  ...   1.56   3.20   4.29   4.78   5.49   4.77   4.39   4.09   4.70   5.13
# 4  ...  10.54  11.30  12.13  11.73  11.89  10.07   8.73   7.17   6.47   5.90
#
# [5 rows x 521 columns]

# %%
# localidade dividida em 'id', 'nivel' e 'nome'
# remover 'id' e 'nivel'
df_clean.drop(columns=['id','nivel'], inplace=True)

# %%
df_clean
# Out:
#                                 variavel unidade    nome 197912 198001 198002  \
# 0                 IPCA - Variação mensal          Brasil    ...   6.62   4.62
# 1   IPCA - Variação acumulada em 3 meses          Brasil    ...    ...    ...
# 2   IPCA - Variação acumulada em 6 meses          Brasil    ...    ...    ...
# 3       IPCA - Variação acumulada no ano          Brasil    ...   6.62  11.54
# 4  IPCA - Variação acumulada em 12 meses          Brasil    ...    ...    ...
#
#   198003 198004 198005 198006  ... 202202 202203 202204 202205 202206 202207  \
# 0   6.04   5.29   5.70   5.31  ...   1.01   1.62   1.06   0.47   0.67  -0.68
# 1  18.27  16.80  18.01  17.19  ...   2.30   3.20   3.73   3.18   2.22   0.46
# 2    ...    ...    ...  38.61  ...   5.77   6.25   6.05   5.55   5.49   4.21
# 3  18.27  24.53  31.63  38.61  ...   1.56   3.20   4.29   4.78   5.49   4.77
# 4    ...    ...    ...    ...  ...  10.54  11.30  12.13  11.73  11.89  10.07
#
#   202208 202209 202210 202211
# 0  -0.36  -0.29   0.59   0.41
# 1  -0.37  -1.32  -0.06   0.71
# 2   2.79   0.86   0.39   0.33
# 3   4.39   4.09   4.70   5.13
# 4   8.73   7.17   6.47   5.90
#
# [5 rows x 519 columns]

# %%
df_clean.variavel[0]
# Out:
# 'IPCA - Variação mensal'

# %%
df_clean = df_clean.melt(id_vars=['variavel','unidade','nome'], var_name='ano/mês',value_name='valor')

# %% [markdown]
# ### formatar datas

# %%
def format_anomes(data_str):
    """"""
    ano = int(data_str[:4])
    mês = int(data_str[-2:])
    dt = datetime.date(ano,mês, 1)
    return dt.strftime('%b/%Y')

df_clean['ano/mês'] = df_clean['ano/mês'].apply(lambda x: format_anomes(x))

# %% [markdown]
# ### itens nulos e formatos

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variavel  1032 non-null   object
#  1   unidade   1032 non-null   object
#  2   nome      1032 non-null   object
#  3   ano/mês   1032 non-null   object
#  4   valor     1031 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 40.4+ KB

# %% [markdown]
# ### corrigir NANs

# %%
df_clean.replace(to_replace=['-','...'], value=np.nan, inplace=True)

# %%
# corrigir formatos
df_clean['valor'] = df_clean['valor'].astype('float')

# %%
df_clean
# Out:
#                                    variavel unidade    nome   ano/mês  valor
# 0                    IPCA - Variação mensal          Brasil  Dec/1979    NaN
# 1      IPCA - Variação acumulada em 3 meses          Brasil  Dec/1979    NaN
# 2      IPCA - Variação acumulada em 6 meses          Brasil  Dec/1979    NaN
# 3          IPCA - Variação acumulada no ano          Brasil  Dec/1979    NaN
# 4     IPCA - Variação acumulada em 12 meses          Brasil  Dec/1979    NaN
# ...                                     ...     ...     ...       ...    ...
# 2575                 IPCA - Variação mensal          Brasil  Nov/2022   0.41
# 2576   IPCA - Variação acumulada em 3 meses          Brasil  Nov/2022   0.71
# 2577   IPCA - Variação acumulada em 6 meses          Brasil  Nov/2022   0.33
# 2578       IPCA - Variação acumulada no ano          Brasil  Nov/2022   5.13
# 2579  IPCA - Variação acumulada em 12 meses          Brasil  Nov/2022   5.90
#
# [2580 rows x 5 columns]

# %%
nome_arquivo = 'IPCA_série_histórica.csv'

df_clean.to_csv(nome_arquivo, encoding='LATIN-1', index=False, sep=';', decimal=',')

# %% [markdown]
# ***
#
# ## data analysis

# %%
df_plot = df_clean[['espécie','ano','hectares']].groupby(['espécie','ano']).sum().reset_index()
df_plot
# Out:
#             espécie   ano   hectares
# 0         Eucalipto  2013  6315444.0
# 1         Eucalipto  2014  6952509.0
# 2         Eucalipto  2015  7444625.0
# 3         Eucalipto  2016  7457676.0
# 4         Eucalipto  2017  7432753.0
# 5         Eucalipto  2018  7536728.0
# 6         Eucalipto  2019  7452050.0
# 7         Eucalipto  2020  7440169.0
# 8         Eucalipto  2021  7295309.0
# 9   Outras espécies  2013   370753.0
# 10  Outras espécies  2014   364998.0
# 11  Outras espécies  2015   427762.0
# 12  Outras espécies  2016   407059.0
# 13  Outras espécies  2017   379971.0
# 14  Outras espécies  2018   369451.0
# 15  Outras espécies  2019   386349.0
# 16  Outras espécies  2020   355217.0
# 17  Outras espécies  2021   380693.0
# 18            Pinus  2013  1611338.0
# 19            Pinus  2014  2049234.0
# 20            Pinus  2015  2065560.0
# 21            Pinus  2016  2003855.0
# 22            Pinus  2017  1951059.0
# 23            Pinus  2018  1958771.0
# 24            Pinus  2019  1848670.0
# 25            Pinus  2020  1830342.0
# 26            Pinus  2021  1810837.0

# %%
plt.scatter(df_plot['ano'], df_plot['hectares'])

# %%
sns.scatterplot(data=df_clean, x='ano', y='hectares', style='espécie', hue='espécie', size='hectares')
# Out:
# <AxesSubplot:xlabel='ano', ylabel='hectares'>
